# %%
import pandas as pa
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as npy

data = pa.read_csv("../DataVis/IBM_HR_ATTRITION.csv")

data.info()

sb.catplot(x='JobSatisfaction', y='Attrition', data=data, kind='box')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sb.boxplot(x="JobSatisfaction", y="Attrition", data=data)

# %%
sb.catplot(x="TotalWorkingYears", y="Attrition", data = data, kind= "box", height=10)

# %%
JobSatisfaction = data[ data['TotalWorkingYears'] < 20 ] 
sb.catplot(x="TotalWorkingYears", y="Attrition", data = JobSatisfaction, kind= "box", height=10)
data['JobSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
data.Attrition = data.Attrition.replace(to_replace = ["Yes", "No"], value=[1,0])
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
sb.catplot(x="EducationField", y="Attrition", data= data, kind="bar", height=10)

# %%
sb.distplot(data.MonthlyIncome, color="blue")

# %%
sb.distplot(data.MonthlyIncome[data.MonthlyIncome < 5000], color="blue")

# %%
sb.lmplot(x="DistanceFromHome", y="Attrition", data= data, logistic = True, height=10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-db606d3ea76e> in <module>
# ----> 1 sb.lmplot(x="DistanceFromHome", y="Attrition", data= data, logistic = True, height=10)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     614         scatter_kws=scatter_kws, line_kws=line_kws,
#     615         )
# --> 616     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     617
#     618     # Add a legend
#
# ...

# %%
sb.lmplot(x="YearsAtCompany", y="Attrition", data= data, logistic = True, height=10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-a21851306b39> in <module>
# ----> 1 sb.lmplot(x="YearsAtCompany", y="Attrition", data= data, logistic = True, height=10)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     614         scatter_kws=scatter_kws, line_kws=line_kws,
#     615         )
# --> 616     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     617
#     618     # Add a legend
#
# ...
