# %%
# Exercice 1

import pandas as pa
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as npy

# %%
# Exercice 2

data = pa.read_csv("../DataVis/house_pricing.csv")

data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# Exercice 3

sb.scatterplot('LotArea', 'SalePrice', data=data)

# %%
# Exercice 4

sb.scatterplot('LotArea', 'SalePrice', data=data)
plt.xlim(0, 20000)
plt.ylim(0, 500000)
# Out:
# (0.0, 500000.0)

# %%
# Exercice 5

sb.scatterplot('LotFrontage', 'LotArea', data=data)

# %%
# Exercice 6

sb.scatterplot('LotFrontage', 'LotArea', data=data)

plt.xlim(0, 200)
plt.ylim(0, 100000)
# Out:
# (0.0, 100000.0)
