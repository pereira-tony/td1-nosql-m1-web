# %%
# Exercice 1

import pandas as pa
import seaborn as sb
import matplotlib.pyplot as plt

# %%
# Exercice 2

data = pa.read_csv("../DataVis/sales_predictions.csv")

sb.relplot('date', 'item_price', data=data)

# %%
# Exercice 3

data2 = data.sample(n = 50)

sb.relplot('date', 'item_price', data=data2)

# %%
# Exercice 4

# plt.figure(figsize(20,6)) ne fonctionne pas avec le relplot
sb.relplot('date', 'item_price', data=data2,  height=20, aspect=6)

# %%
# Exercice 5 et 6


data2["date"]= pa.to_datetime(data2["date"]) 

sb.relplot('date', 'item_price', data=data2,  height=6, aspect=2)
